# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

party_colors = {
    'SPD': 'red',
    'CDU': 'black',
    'AfD': 'blue',
    'FDP': 'yellow',
    'Bündnis 90/Die Grünen': 'green',
    'Die Linke': 'purple',
    'CSU': 'lightblue',
    'Fraktionslos': 'grey'
}

start_end_date = [['01/1/2020','01/31/2020'],
                  ['02/1/2020', '02/29/2020'],
                  ['03/1/2020', '03/31/2020'],
                  ['04/1/2020', '04/30/2020'],
                  ['05/1/2020', '05/31/2020'],
                  ['06/1/2020', '06/30/2020'],
                  ['07/1/2020', '07/31/2020'],
                  ['08/1/2020', '08/31/2020'],
                  ['09/1/2020', '09/30/2020'],
                  ['10/1/2020', '10/31/2020'],
                  ['11/1/2020', '11/30/2020'],
                  ['12/1/2020', '12/31/2020'],]


popular_covid = pd.read_csv('most_popular_covid_tweets.csv')
popular_non_covid = pd.read_csv('most_popular_non_covid_tweets.csv')
all_popular = pd.read_csv('most_popular_tweets.csv')

# %%
#All popular
df_copy = all_popular.copy()
df_copy['date']=pd.to_datetime(df_copy['date'], utc= True).dt.date
for dates in start_end_date:
    df_per_month = df_copy.loc[(df_copy['date'] >= pd.to_datetime(dates[0], utc= True)) & (df_copy['date'] <= pd.to_datetime(dates[1], utc=True))]
    if not df_per_month.empty:
        df_relevant_columns = df_per_month.drop(['date', 'name', 'screen_name', 'p_user_id', 'tweet'], axis='columns')
        print(df_relevant_columns.shape[0])
        fig = plt.figure(figsize=(12, 4))
        chart = sns.countplot(data=df_relevant_columns,
                            x='party',
                            order=df_relevant_columns['party'].value_counts().index,
                            palette=party_colors)
        chart.set(ylabel='number of politicians',
                title='Number of Politicians per Party' + str(dates))
        plt.show()
# Out:
# 7
# 22
# 45
# 7
# 17
# 15
# 18
# 27
# 14
# 15
# 22
# 29

# %%
#Covid popular
df_copy = popular_covid.copy()
df_copy['date']=pd.to_datetime(df_copy['date'], utc= True).dt.date
for dates in start_end_date:
    df_per_month = df_copy.loc[(df_copy['date'] >= pd.to_datetime(dates[0], utc= True)) & (df_copy['date'] <= pd.to_datetime(dates[1], utc=True))]
    if not df_per_month.empty:
        df_relevant_columns = df_per_month.drop(['date', 'name', 'screen_name', 'p_user_id', 'tweet'], axis='columns')
        print(df_relevant_columns.shape[0])
        fig = plt.figure(figsize=(12, 4))
        chart = sns.countplot(data=df_relevant_columns,
                            x='party',
                            order=df_relevant_columns['party'].value_counts().index,
                            palette=party_colors)
        chart.set(ylabel='number of politicians',
                title='Number of Politicians per Party' + str(dates))
        plt.show()
# Out:
# 4
# 34
# 3
# 8
# 3
# 6
# 13
# 5
# 11
# 15
# 18

# %%
#Non-Covid popular
df_copy = popular_non_covid.copy()
df_copy['date']=pd.to_datetime(df_copy['date'], utc= True).dt.date
for dates in start_end_date:
    df_per_month = df_copy.loc[(df_copy['date'] >= pd.to_datetime(dates[0], utc= True)) & (df_copy['date'] <= pd.to_datetime(dates[1], utc=True))]
    if not df_per_month.empty:
        df_relevant_columns = df_per_month.drop(['date', 'name', 'screen_name', 'p_user_id', 'tweet'], axis='columns')
        print(df_relevant_columns.shape[0])
        fig = plt.figure(figsize=(12, 4))
        chart = sns.countplot(data=df_relevant_columns,
                            x='party',
                            order=df_relevant_columns['party'].value_counts().index,
                            palette=party_colors)
        chart.set(ylabel='number of politicians',
                title='Number of Politicians per Party' + str(dates))
        plt.show()
# Out:
# 7
# 18
# 11
# 4
# 9
# 12
# 12
# 14
# 9
# 4
# 7
# 11
